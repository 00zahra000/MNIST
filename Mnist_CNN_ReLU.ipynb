# %%
from numpy import mean
from numpy import std
from matplotlib import pyplot
from sklearn.model_selection import KFold
from keras.datasets import fashion_mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import Adadelta, Adam, SGD
 
# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = fashion_mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY
 
# scale
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	return train_norm, test_norm

#cnn model with Relu
def define_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
  # model.add(Dropout(rate=0.3))
  model.add(Dense(10, activation='softmax'))
	# compile
  opt = Adadelta(lr=0.01)
  model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
  return model
 
# evaluate the model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=1)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows of train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit
		history = model.fit(trainX, trainY, epochs=50, batch_size=64, validation_data=(testX, testY), verbose=2)
		# evaluate 
		_, acc = model.evaluate(testX, testY, verbose=2)
		print('Accuracy> %.2f' % (acc * 100.0))
		# append scores
		scores.append(acc)
		histories.append(history)
	return scores, histories

pyplot.figure(figsize=(14,6))
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(211)
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='test')
		# plot accuracy
		pyplot.subplot(212)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()
 
 
# run the code
def run_test():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)


run_test()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 750/750 - 4s - loss: 0.9634 - accuracy: 0.6970 - val_loss: 0.6473 - val_accuracy: 0.7866
# Epoch 2/50
# 750/750 - 4s - loss: 0.5765 - accuracy: 0.8125 - val_loss: 0.5328 - val_accuracy: 0.8244
# Epoch 3/50
# 750/750 - 4s - loss: 0.5035 - accuracy: 0.8316 - val_loss: 0.4844 - val_accuracy: 0.8363
# Epoch 4/50
# 750/750 - 4s - loss: 0.4659 - accuracy: 0.8436 - val_loss: 0.4540 - val_accuracy: 0.8429
# Epoch 5/50
# 750/750 - 4s - loss: 0.4413 - accuracy: 0.8496 - val_loss: 0.4346 - val_accuracy: 0.8508
# Epoch 6/50
# 750/750 - 4s - loss: 0.4238 - accuracy: 0.8557 - val_loss: 0.4239 - val_accuracy: 0.8528
# Epoch 7/50
# 750/750 - 4s - loss: 0.4099 - accuracy: 0.8614 - val_loss: 0.4087 - val_accuracy: 0.8575
# Epoch 8/50
# 750/750 - 4s - loss: 0.3983 - accuracy: 0.8642 - val_loss: 0.3987 - val_accuracy: 0.8606
# Epoch 9/50
# 750/750 - 4s - loss: 0.3886 - accuracy: 0.8664 - val_loss: 0.3913 - val_accuracy: 0.8628
# Epoch 10/50
# 750/750 - 4s - loss: 0.3801 - accuracy: 0.8708 - val_loss: 0.3825 - val_accuracy: 0.8669
# Epoch 11/50
# 750/750 - 4s - loss: 0.3731 - accuracy: 0.8722 - val_loss: 0.3762 - val_accuracy: 0.8697
# Epoch 12/50
# 750/750 - 4s - loss: 0.3663 - accuracy: 0.8739 - val_loss: 0.3727 - val_accuracy: 0.8698
# Epoch 13/50
# 750/750 - 4s - loss: 0.3606 - accuracy: 0.8769 - val_loss: 0.3678 - val_accuracy: 0.8713
# Epoch 14/50
# 750/750 - 4s - loss: 0.3554 - accuracy: 0.8780 - val_loss: 0.3582 - val_accuracy: 0.8740
# Epoch 15/50
# 750/750 - 4s - loss: 0.3507 - accuracy: 0.8789 - val_loss: 0.3561 - val_accuracy: 0.8758
# Epoch 16/50
# 750/750 - 4s - loss: 0.3459 - accuracy: 0.8811 - val_loss: 0.3530 - val_accuracy: 0.8763
# Epoch 17/50
# 750/750 - 4s - loss: 0.3415 - accuracy: 0.8829 - val_loss: 0.3471 - val_accuracy: 0.8796
# Epoch 18/50
# 750/750 - 4s - loss: 0.3372 - accuracy: 0.8839 - val_loss: 0.3466 - val_accuracy: 0.8789
# Epoch 19/50
# 750/750 - 4s - loss: 0.3343 - accuracy: 0.8850 - val_loss: 0.3413 - val_accuracy: 0.8800
# Epoch 20/50
# 750/750 - 4s - loss: 0.3303 - accuracy: 0.8859 - val_loss: 0.3431 - val_accuracy: 0.8789
# Epoch 21/50
# 750/750 - 4s - loss: 0.3272 - accuracy: 0.8875 - val_loss: 0.3417 - val_accuracy: 0.8788
# Epoch 22/50
# 750/750 - 4s - loss: 0.3236 - accuracy: 0.8883 - val_loss: 0.3340 - val_accuracy: 0.8823
# Epoch 23/50
# 750/750 - 4s - loss: 0.3206 - accuracy: 0.8896 - val_loss: 0.3329 - val_accuracy: 0.8827
# Epoch 24/50
# 750/750 - 4s - loss: 0.3176 - accuracy: 0.8902 - val_loss: 0.3293 - val_accuracy: 0.8841
# Epoch 25/50
# 750/750 - 4s - loss: 0.3149 - accuracy: 0.8917 - val_loss: 0.3243 - val_accuracy: 0.8872
# Epoch 26/50
# 750/750 - 4s - loss: 0.3124 - accuracy: 0.8923 - val_loss: 0.3226 - val_accuracy: 0.8876
# Epoch 27/50
# 750/750 - 4s - loss: 0.3097 - accuracy: 0.8924 - val_loss: 0.3208 - val_accuracy: 0.8879
# Epoch 28/50
# 750/750 - 4s - loss: 0.3074 - accuracy: 0.8940 - val_loss: 0.3192 - val_accuracy: 0.8903
# Epoch 29/50
# 750/750 - 4s - loss: 0.3048 - accuracy: 0.8944 - val_loss: 0.3183 - val_accuracy: 0.8869
# Epoch 30/50
# 750/750 - 4s - loss: 0.3024 - accuracy: 0.8953 - val_loss: 0.3167 - val_accuracy: 0.8892
# Epoch 31/50
# 750/750 - 4s - loss: 0.2998 - accuracy: 0.8966 - val_loss: 0.3141 - val_accuracy: 0.8913
# Epoch 32/50
# 750/750 - 4s - loss: 0.2981 - accuracy: 0.8968 - val_loss: 0.3123 - val_accuracy: 0.8915
# Epoch 33/50
# 750/750 - 4s - loss: 0.2959 - accuracy: 0.8978 - val_loss: 0.3154 - val_accuracy: 0.8896
# Epoch 34/50
# 750/750 - 4s - loss: 0.2937 - accuracy: 0.8980 - val_loss: 0.3098 - val_accuracy: 0.8923
# Epoch 35/50
# 750/750 - 4s - loss: 0.2919 - accuracy: 0.8992 - val_loss: 0.3110 - val_accuracy: 0.8917
# Epoch 36/50
# 750/750 - 4s - loss: 0.2897 - accuracy: 0.8999 - val_loss: 0.3099 - val_accuracy: 0.8919
# Epoch 37/50
# 750/750 - 4s - loss: 0.2880 - accuracy: 0.8997 - val_loss: 0.3081 - val_accuracy: 0.8903
# Epoch 38/50
# 750/750 - 4s - loss: 0.2860 - accuracy: 0.9016 - val_loss: 0.3030 - val_accuracy: 0.8938
# Epoch 39/50
# 750/750 - 4s - loss: 0.2844 - accuracy: 0.9022 - val_loss: 0.3024 - val_accuracy: 0.8943
# Epoch 40/50
# 750/750 - 4s - loss: 0.2825 - accuracy: 0.9025 - val_loss: 0.3022 - val_accuracy: 0.8939
# Epoch 41/50
# 750/750 - 4s - loss: 0.2810 - accuracy: 0.9032 - val_loss: 0.3004 - val_accuracy: 0.8940
# Epoch 42/50
# 750/750 - 4s - loss: 0.2791 - accuracy: 0.9025 - val_loss: 0.2997 - val_accuracy: 0.8953
# Epoch 43/50
# 750/750 - 4s - loss: 0.2775 - accuracy: 0.9043 - val_loss: 0.2977 - val_accuracy: 0.8938
# Epoch 44/50
# 750/750 - 4s - loss: 0.2755 - accuracy: 0.9051 - val_loss: 0.2971 - val_accuracy: 0.8953
# Epoch 45/50
# 750/750 - 4s - loss: 0.2744 - accuracy: 0.9054 - val_loss: 0.3022 - val_accuracy: 0.8924
# Epoch 46/50
# 750/750 - 4s - loss: 0.2727 - accuracy: 0.9060 - val_loss: 0.2984 - val_accuracy: 0.8957
# Epoch 47/50
# 750/750 - 4s - loss: 0.2707 - accuracy: 0.9061 - val_loss: 0.2948 - val_accuracy: 0.8978
# Epoch 48/50
# 750/750 - 4s - loss: 0.2696 - accuracy: 0.9066 - val_loss: 0.2945 - val_accuracy: 0.8966
# Epoch 49/50
# 750/750 - 4s - loss: 0.2680 - accuracy: 0.9069 - val_loss: 0.2919 - val_accuracy: 0.8967
# Epoch 50/50
# 750/750 - 4s - loss: 0.2669 - accuracy: 0.9072 - val_loss: 0.2915 - val_accuracy: 0.8974
# 375/375 - 1s - loss: 0.2915 - accuracy: 0.8974
# Accuracy> 89.74
# Epoch 1/50
# 750/750 - 4s - loss: 1.0486 - accuracy: 0.6859 - val_loss: 0.6884 - val_accuracy: 0.7779
# Epoch 2/50
# 750/750 - 4s - loss: 0.6150 - accuracy: 0.8040 - val_loss: 0.5603 - val_accuracy: 0.8129
# Epoch 3/50
# 750/750 - 4s - loss: 0.5319 - accuracy: 0.8239 - val_loss: 0.5044 - val_accuracy: 0.8282
# Epoch 4/50
# 750/750 - 4s - loss: 0.4889 - accuracy: 0.8370 - val_loss: 0.4725 - val_accuracy: 0.8406
# Epoch 5/50
# 750/750 - 4s - loss: 0.4605 - accuracy: 0.8461 - val_loss: 0.4486 - val_accuracy: 0.8472
# Epoch 6/50
# 750/750 - 4s - loss: 0.4404 - accuracy: 0.8517 - val_loss: 0.4328 - val_accuracy: 0.8533
# Epoch 7/50
# 750/750 - 4s - loss: 0.4247 - accuracy: 0.8564 - val_loss: 0.4183 - val_accuracy: 0.8548
# Epoch 8/50
# 750/750 - 4s - loss: 0.4121 - accuracy: 0.8616 - val_loss: 0.4076 - val_accuracy: 0.8599
# Epoch 9/50
# 750/750 - 4s - loss: 0.4014 - accuracy: 0.8646 - val_loss: 0.3979 - val_accuracy: 0.8636
# Epoch 10/50
# 750/750 - 4s - loss: 0.3921 - accuracy: 0.8661 - val_loss: 0.3917 - val_accuracy: 0.8639
# Epoch 11/50
# 750/750 - 4s - loss: 0.3838 - accuracy: 0.8695 - val_loss: 0.3852 - val_accuracy: 0.8658
# Epoch 12/50
# 750/750 - 4s - loss: 0.3768 - accuracy: 0.8712 - val_loss: 0.3770 - val_accuracy: 0.8686
# Epoch 13/50
# 750/750 - 4s - loss: 0.3705 - accuracy: 0.8739 - val_loss: 0.3711 - val_accuracy: 0.8696
# Epoch 14/50
# 750/750 - 4s - loss: 0.3645 - accuracy: 0.8749 - val_loss: 0.3661 - val_accuracy: 0.8726
# Epoch 15/50
# 750/750 - 4s - loss: 0.3594 - accuracy: 0.8767 - val_loss: 0.3618 - val_accuracy: 0.8745
# Epoch 16/50
# 750/750 - 4s - loss: 0.3542 - accuracy: 0.8785 - val_loss: 0.3588 - val_accuracy: 0.8740
# Epoch 17/50
# 750/750 - 4s - loss: 0.3493 - accuracy: 0.8802 - val_loss: 0.3574 - val_accuracy: 0.8748
# Epoch 18/50
# 750/750 - 4s - loss: 0.3452 - accuracy: 0.8815 - val_loss: 0.3499 - val_accuracy: 0.8776
# Epoch 19/50
# 750/750 - 4s - loss: 0.3408 - accuracy: 0.8835 - val_loss: 0.3457 - val_accuracy: 0.8783
# Epoch 20/50
# 750/750 - 4s - loss: 0.3372 - accuracy: 0.8845 - val_loss: 0.3423 - val_accuracy: 0.8792
# Epoch 21/50
# 750/750 - 4s - loss: 0.3336 - accuracy: 0.8852 - val_loss: 0.3398 - val_accuracy: 0.8798
# Epoch 22/50
# 750/750 - 4s - loss: 0.3302 - accuracy: 0.8866 - val_loss: 0.3371 - val_accuracy: 0.8813
# Epoch 23/50
# 750/750 - 4s - loss: 0.3267 - accuracy: 0.8873 - val_loss: 0.3378 - val_accuracy: 0.8808
# Epoch 24/50
# 750/750 - 4s - loss: 0.3236 - accuracy: 0.8884 - val_loss: 0.3314 - val_accuracy: 0.8827
# Epoch 25/50
# 750/750 - 4s - loss: 0.3203 - accuracy: 0.8897 - val_loss: 0.3288 - val_accuracy: 0.8829
# Epoch 26/50
# 750/750 - 4s - loss: 0.3178 - accuracy: 0.8907 - val_loss: 0.3272 - val_accuracy: 0.8832
# Epoch 27/50
# 750/750 - 4s - loss: 0.3144 - accuracy: 0.8915 - val_loss: 0.3239 - val_accuracy: 0.8848
# Epoch 28/50
# 750/750 - 4s - loss: 0.3118 - accuracy: 0.8922 - val_loss: 0.3225 - val_accuracy: 0.8852
# Epoch 29/50
# 750/750 - 4s - loss: 0.3094 - accuracy: 0.8929 - val_loss: 0.3225 - val_accuracy: 0.8857
# Epoch 30/50
# 750/750 - 4s - loss: 0.3069 - accuracy: 0.8929 - val_loss: 0.3190 - val_accuracy: 0.8863
# Epoch 31/50
# 750/750 - 4s - loss: 0.3042 - accuracy: 0.8946 - val_loss: 0.3170 - val_accuracy: 0.8878
# Epoch 32/50
# 750/750 - 4s - loss: 0.3021 - accuracy: 0.8960 - val_loss: 0.3152 - val_accuracy: 0.8886
# Epoch 33/50
# 750/750 - 4s - loss: 0.2998 - accuracy: 0.8956 - val_loss: 0.3135 - val_accuracy: 0.8882
# Epoch 34/50
# 750/750 - 4s - loss: 0.2971 - accuracy: 0.8970 - val_loss: 0.3114 - val_accuracy: 0.8898
# Epoch 35/50
# 750/750 - 4s - loss: 0.2952 - accuracy: 0.8978 - val_loss: 0.3101 - val_accuracy: 0.8903
# Epoch 36/50
# 750/750 - 4s - loss: 0.2932 - accuracy: 0.8985 - val_loss: 0.3075 - val_accuracy: 0.8914
# Epoch 37/50
# 750/750 - 4s - loss: 0.2909 - accuracy: 0.8986 - val_loss: 0.3070 - val_accuracy: 0.8897
# Epoch 38/50
# 750/750 - 4s - loss: 0.2892 - accuracy: 0.8993 - val_loss: 0.3050 - val_accuracy: 0.8923
# Epoch 39/50
# 750/750 - 4s - loss: 0.2870 - accuracy: 0.8998 - val_loss: 0.3034 - val_accuracy: 0.8913
# Epoch 40/50
# 750/750 - 4s - loss: 0.2848 - accuracy: 0.9006 - val_loss: 0.3038 - val_accuracy: 0.8915
# Epoch 41/50
# 750/750 - 4s - loss: 0.2831 - accuracy: 0.9024 - val_loss: 0.3025 - val_accuracy: 0.8903
# Epoch 42/50
# 750/750 - 4s - loss: 0.2816 - accuracy: 0.9013 - val_loss: 0.3005 - val_accuracy: 0.8924
# Epoch 43/50
# 750/750 - 4s - loss: 0.2796 - accuracy: 0.9026 - val_loss: 0.3060 - val_accuracy: 0.8929
# Epoch 44/50
# 750/750 - 4s - loss: 0.2778 - accuracy: 0.9028 - val_loss: 0.3005 - val_accuracy: 0.8923
# Epoch 45/50
# 750/750 - 4s - loss: 0.2758 - accuracy: 0.9043 - val_loss: 0.2952 - val_accuracy: 0.8962
# Epoch 46/50
# 750/750 - 4s - loss: 0.2743 - accuracy: 0.9040 - val_loss: 0.2937 - val_accuracy: 0.8962
# Epoch 47/50
# 750/750 - 4s - loss: 0.2724 - accuracy: 0.9048 - val_loss: 0.2927 - val_accuracy: 0.8962
# Epoch 48/50
# 750/750 - 4s - loss: 0.2710 - accuracy: 0.9053 - val_loss: 0.2919 - val_accuracy: 0.8974
# Epoch 49/50
# 750/750 - 4s - loss: 0.2693 - accuracy: 0.9057 - val_loss: 0.2903 - val_accuracy: 0.8973
# Epoch 50/50
# 750/750 - 4s - loss: 0.2679 - accuracy: 0.9063 - val_loss: 0.2896 - val_accuracy: 0.8977
# 375/375 - 1s - loss: 0.2896 - accuracy: 0.8977
# Accuracy> 89.77
# Epoch 1/50
# 750/750 - 4s - loss: 0.9454 - accuracy: 0.7144 - val_loss: 0.6169 - val_accuracy: 0.8069
# Epoch 2/50
# 750/750 - 4s - loss: 0.5521 - accuracy: 0.8205 - val_loss: 0.5180 - val_accuracy: 0.8268
# Epoch 3/50
# 750/750 - 4s - loss: 0.4813 - accuracy: 0.8392 - val_loss: 0.4681 - val_accuracy: 0.8455
# Epoch 4/50
# 750/750 - 4s - loss: 0.4438 - accuracy: 0.8509 - val_loss: 0.4397 - val_accuracy: 0.8543
# Epoch 5/50
# 750/750 - 4s - loss: 0.4189 - accuracy: 0.8596 - val_loss: 0.4194 - val_accuracy: 0.8629
# Epoch 6/50
# 750/750 - 4s - loss: 0.4015 - accuracy: 0.8640 - val_loss: 0.4072 - val_accuracy: 0.8667
# Epoch 7/50
# 750/750 - 4s - loss: 0.3874 - accuracy: 0.8686 - val_loss: 0.3959 - val_accuracy: 0.8703
# Epoch 8/50
# 750/750 - 4s - loss: 0.3762 - accuracy: 0.8723 - val_loss: 0.3861 - val_accuracy: 0.8727
# Epoch 9/50
# 750/750 - 4s - loss: 0.3667 - accuracy: 0.8748 - val_loss: 0.3803 - val_accuracy: 0.8748
# Epoch 10/50
# 750/750 - 4s - loss: 0.3583 - accuracy: 0.8777 - val_loss: 0.3726 - val_accuracy: 0.8775
# Epoch 11/50
# 750/750 - 4s - loss: 0.3509 - accuracy: 0.8793 - val_loss: 0.3667 - val_accuracy: 0.8787
# Epoch 12/50
# 750/750 - 4s - loss: 0.3446 - accuracy: 0.8823 - val_loss: 0.3644 - val_accuracy: 0.8792
# Epoch 13/50
# 750/750 - 4s - loss: 0.3385 - accuracy: 0.8841 - val_loss: 0.3565 - val_accuracy: 0.8834
# Epoch 14/50
# 750/750 - 4s - loss: 0.3329 - accuracy: 0.8858 - val_loss: 0.3511 - val_accuracy: 0.8831
# Epoch 15/50
# 750/750 - 4s - loss: 0.3281 - accuracy: 0.8863 - val_loss: 0.3518 - val_accuracy: 0.8838
# Epoch 16/50
# 750/750 - 4s - loss: 0.3239 - accuracy: 0.8880 - val_loss: 0.3445 - val_accuracy: 0.8857
# Epoch 17/50
# 750/750 - 4s - loss: 0.3196 - accuracy: 0.8900 - val_loss: 0.3421 - val_accuracy: 0.8863
# Epoch 18/50
# 750/750 - 4s - loss: 0.3158 - accuracy: 0.8920 - val_loss: 0.3425 - val_accuracy: 0.8845
# Epoch 19/50
# 750/750 - 4s - loss: 0.3122 - accuracy: 0.8918 - val_loss: 0.3381 - val_accuracy: 0.8859
# Epoch 20/50
# 750/750 - 4s - loss: 0.3092 - accuracy: 0.8931 - val_loss: 0.3344 - val_accuracy: 0.8890
# Epoch 21/50
# 750/750 - 4s - loss: 0.3055 - accuracy: 0.8946 - val_loss: 0.3328 - val_accuracy: 0.8888
# Epoch 22/50
# 750/750 - 4s - loss: 0.3026 - accuracy: 0.8957 - val_loss: 0.3309 - val_accuracy: 0.8884
# Epoch 23/50
# 750/750 - 4s - loss: 0.2999 - accuracy: 0.8963 - val_loss: 0.3259 - val_accuracy: 0.8901
# Epoch 24/50
# 750/750 - 4s - loss: 0.2969 - accuracy: 0.8974 - val_loss: 0.3247 - val_accuracy: 0.8917
# Epoch 25/50
# 750/750 - 4s - loss: 0.2944 - accuracy: 0.8986 - val_loss: 0.3216 - val_accuracy: 0.8932
# Epoch 26/50
# 750/750 - 4s - loss: 0.2918 - accuracy: 0.8993 - val_loss: 0.3232 - val_accuracy: 0.8904
# Epoch 27/50
# 750/750 - 4s - loss: 0.2892 - accuracy: 0.9003 - val_loss: 0.3194 - val_accuracy: 0.8919
# Epoch 28/50
# 750/750 - 4s - loss: 0.2871 - accuracy: 0.9004 - val_loss: 0.3162 - val_accuracy: 0.8932
# Epoch 29/50
# 750/750 - 4s - loss: 0.2848 - accuracy: 0.9013 - val_loss: 0.3154 - val_accuracy: 0.8938
# Epoch 30/50
# 750/750 - 4s - loss: 0.2827 - accuracy: 0.9019 - val_loss: 0.3162 - val_accuracy: 0.8920
# Epoch 31/50
# 750/750 - 4s - loss: 0.2803 - accuracy: 0.9034 - val_loss: 0.3149 - val_accuracy: 0.8937
# Epoch 32/50
# 750/750 - 4s - loss: 0.2785 - accuracy: 0.9040 - val_loss: 0.3100 - val_accuracy: 0.8947
# Epoch 33/50
# 750/750 - 4s - loss: 0.2766 - accuracy: 0.9038 - val_loss: 0.3120 - val_accuracy: 0.8947
# Epoch 34/50
# 750/750 - 4s - loss: 0.2745 - accuracy: 0.9053 - val_loss: 0.3094 - val_accuracy: 0.8959
# Epoch 35/50
# 750/750 - 4s - loss: 0.2727 - accuracy: 0.9057 - val_loss: 0.3132 - val_accuracy: 0.8928
# Epoch 36/50
# 750/750 - 4s - loss: 0.2710 - accuracy: 0.9061 - val_loss: 0.3045 - val_accuracy: 0.8969
# Epoch 37/50
# 750/750 - 4s - loss: 0.2688 - accuracy: 0.9077 - val_loss: 0.3039 - val_accuracy: 0.8967
# Epoch 38/50
# 750/750 - 4s - loss: 0.2675 - accuracy: 0.9069 - val_loss: 0.3037 - val_accuracy: 0.8981
# Epoch 39/50
# 750/750 - 4s - loss: 0.2657 - accuracy: 0.9084 - val_loss: 0.3033 - val_accuracy: 0.8979
# Epoch 40/50
# 750/750 - 4s - loss: 0.2640 - accuracy: 0.9092 - val_loss: 0.3029 - val_accuracy: 0.8972
# Epoch 41/50
# 750/750 - 4s - loss: 0.2624 - accuracy: 0.9091 - val_loss: 0.3012 - val_accuracy: 0.8981
# Epoch 42/50
# 750/750 - 4s - loss: 0.2606 - accuracy: 0.9097 - val_loss: 0.3023 - val_accuracy: 0.8987
# Epoch 43/50
# 750/750 - 4s - loss: 0.2595 - accuracy: 0.9103 - val_loss: 0.2980 - val_accuracy: 0.9007
# Epoch 44/50
# 750/750 - 4s - loss: 0.2577 - accuracy: 0.9115 - val_loss: 0.2990 - val_accuracy: 0.8986
# Epoch 45/50
# 750/750 - 4s - loss: 0.2567 - accuracy: 0.9114 - val_loss: 0.2951 - val_accuracy: 0.9003
# Epoch 46/50
# 750/750 - 4s - loss: 0.2549 - accuracy: 0.9131 - val_loss: 0.2976 - val_accuracy: 0.8976
# Epoch 47/50
# 750/750 - 4s - loss: 0.2537 - accuracy: 0.9127 - val_loss: 0.2961 - val_accuracy: 0.8995
# Epoch 48/50
# 750/750 - 4s - loss: 0.2521 - accuracy: 0.9124 - val_loss: 0.2922 - val_accuracy: 0.9018
# Epoch 49/50
# 750/750 - 4s - loss: 0.2509 - accuracy: 0.9128 - val_loss: 0.2941 - val_accuracy: 0.9008
# Epoch 50/50
# 750/750 - 4s - loss: 0.2493 - accuracy: 0.9137 - val_loss: 0.2952 - val_accuracy: 0.8982
# 375/375 - 1s - loss: 0.2952 - accuracy: 0.8982
# Accuracy> 89.82
# Epoch 1/50
# 750/750 - 4s - loss: 0.9856 - accuracy: 0.7039 - val_loss: 0.6423 - val_accuracy: 0.7952
# Epoch 2/50
# 750/750 - 4s - loss: 0.5778 - accuracy: 0.8126 - val_loss: 0.5297 - val_accuracy: 0.8251
# Epoch 3/50
# 750/750 - 4s - loss: 0.5014 - accuracy: 0.8342 - val_loss: 0.4778 - val_accuracy: 0.8397
# Epoch 4/50
# 750/750 - 4s - loss: 0.4620 - accuracy: 0.8454 - val_loss: 0.4494 - val_accuracy: 0.8465
# Epoch 5/50
# 750/750 - 4s - loss: 0.4368 - accuracy: 0.8534 - val_loss: 0.4302 - val_accuracy: 0.8518
# Epoch 6/50
# 750/750 - 4s - loss: 0.4185 - accuracy: 0.8594 - val_loss: 0.4133 - val_accuracy: 0.8570
# Epoch 7/50
# 750/750 - 4s - loss: 0.4042 - accuracy: 0.8637 - val_loss: 0.4042 - val_accuracy: 0.8594
# Epoch 8/50
# 750/750 - 4s - loss: 0.3925 - accuracy: 0.8662 - val_loss: 0.3917 - val_accuracy: 0.8662
# Epoch 9/50
# 750/750 - 4s - loss: 0.3824 - accuracy: 0.8711 - val_loss: 0.3844 - val_accuracy: 0.8648
# Epoch 10/50
# 750/750 - 4s - loss: 0.3739 - accuracy: 0.8731 - val_loss: 0.3768 - val_accuracy: 0.8687
# Epoch 11/50
# 750/750 - 4s - loss: 0.3664 - accuracy: 0.8754 - val_loss: 0.3712 - val_accuracy: 0.8712
# Epoch 12/50
# 750/750 - 4s - loss: 0.3597 - accuracy: 0.8775 - val_loss: 0.3673 - val_accuracy: 0.8711
# Epoch 13/50
# 750/750 - 4s - loss: 0.3537 - accuracy: 0.8800 - val_loss: 0.3621 - val_accuracy: 0.8709
# Epoch 14/50
# 750/750 - 4s - loss: 0.3483 - accuracy: 0.8820 - val_loss: 0.3575 - val_accuracy: 0.8763
# Epoch 15/50
# 750/750 - 4s - loss: 0.3433 - accuracy: 0.8835 - val_loss: 0.3517 - val_accuracy: 0.8772
# Epoch 16/50
# 750/750 - 4s - loss: 0.3386 - accuracy: 0.8848 - val_loss: 0.3485 - val_accuracy: 0.8774
# Epoch 17/50
# 750/750 - 4s - loss: 0.3344 - accuracy: 0.8864 - val_loss: 0.3444 - val_accuracy: 0.8809
# Epoch 18/50
# 750/750 - 4s - loss: 0.3303 - accuracy: 0.8871 - val_loss: 0.3417 - val_accuracy: 0.8815
# Epoch 19/50
# 750/750 - 4s - loss: 0.3267 - accuracy: 0.8891 - val_loss: 0.3379 - val_accuracy: 0.8812
# Epoch 20/50
# 750/750 - 4s - loss: 0.3227 - accuracy: 0.8901 - val_loss: 0.3373 - val_accuracy: 0.8804
# Epoch 21/50
# 750/750 - 4s - loss: 0.3200 - accuracy: 0.8909 - val_loss: 0.3340 - val_accuracy: 0.8808
# Epoch 22/50
# 750/750 - 4s - loss: 0.3164 - accuracy: 0.8924 - val_loss: 0.3328 - val_accuracy: 0.8829
# Epoch 23/50
# 750/750 - 4s - loss: 0.3134 - accuracy: 0.8940 - val_loss: 0.3298 - val_accuracy: 0.8842
# Epoch 24/50
# 750/750 - 4s - loss: 0.3107 - accuracy: 0.8937 - val_loss: 0.3260 - val_accuracy: 0.8838
# Epoch 25/50
# 750/750 - 4s - loss: 0.3080 - accuracy: 0.8948 - val_loss: 0.3259 - val_accuracy: 0.8833
# Epoch 26/50
# 750/750 - 4s - loss: 0.3053 - accuracy: 0.8959 - val_loss: 0.3259 - val_accuracy: 0.8833
# Epoch 27/50
# 750/750 - 4s - loss: 0.3029 - accuracy: 0.8960 - val_loss: 0.3204 - val_accuracy: 0.8854
# Epoch 28/50
# 750/750 - 4s - loss: 0.3003 - accuracy: 0.8973 - val_loss: 0.3206 - val_accuracy: 0.8857
# Epoch 29/50
# 750/750 - 4s - loss: 0.2981 - accuracy: 0.8980 - val_loss: 0.3215 - val_accuracy: 0.8843
# Epoch 30/50
# 750/750 - 4s - loss: 0.2954 - accuracy: 0.8986 - val_loss: 0.3153 - val_accuracy: 0.8870
# Epoch 31/50
# 750/750 - 4s - loss: 0.2934 - accuracy: 0.8999 - val_loss: 0.3140 - val_accuracy: 0.8886
# Epoch 32/50
# 750/750 - 4s - loss: 0.2910 - accuracy: 0.9001 - val_loss: 0.3130 - val_accuracy: 0.8872
# Epoch 33/50
# 750/750 - 4s - loss: 0.2892 - accuracy: 0.9008 - val_loss: 0.3122 - val_accuracy: 0.8888
# Epoch 34/50
# 750/750 - 4s - loss: 0.2871 - accuracy: 0.9018 - val_loss: 0.3101 - val_accuracy: 0.8901
# Epoch 35/50
# 750/750 - 4s - loss: 0.2854 - accuracy: 0.9025 - val_loss: 0.3086 - val_accuracy: 0.8903
# Epoch 36/50
# 750/750 - 4s - loss: 0.2831 - accuracy: 0.9038 - val_loss: 0.3101 - val_accuracy: 0.8893
# Epoch 37/50
# 750/750 - 4s - loss: 0.2812 - accuracy: 0.9037 - val_loss: 0.3076 - val_accuracy: 0.8889
# Epoch 38/50
# 750/750 - 4s - loss: 0.2796 - accuracy: 0.9039 - val_loss: 0.3089 - val_accuracy: 0.8888
# Epoch 39/50
# 750/750 - 4s - loss: 0.2779 - accuracy: 0.9049 - val_loss: 0.3078 - val_accuracy: 0.8910
# Epoch 40/50
# 750/750 - 4s - loss: 0.2760 - accuracy: 0.9057 - val_loss: 0.3055 - val_accuracy: 0.8888
# Epoch 41/50
# 750/750 - 4s - loss: 0.2741 - accuracy: 0.9065 - val_loss: 0.3031 - val_accuracy: 0.8910
# Epoch 42/50
# 750/750 - 4s - loss: 0.2727 - accuracy: 0.9066 - val_loss: 0.2993 - val_accuracy: 0.8928
# Epoch 43/50
# 750/750 - 4s - loss: 0.2712 - accuracy: 0.9068 - val_loss: 0.2985 - val_accuracy: 0.8919
# Epoch 44/50
# 750/750 - 4s - loss: 0.2695 - accuracy: 0.9080 - val_loss: 0.2987 - val_accuracy: 0.8934
# Epoch 45/50
# 750/750 - 4s - loss: 0.2678 - accuracy: 0.9083 - val_loss: 0.2966 - val_accuracy: 0.8936
# Epoch 46/50
# 750/750 - 4s - loss: 0.2663 - accuracy: 0.9090 - val_loss: 0.2963 - val_accuracy: 0.8957
# Epoch 47/50
# 750/750 - 4s - loss: 0.2650 - accuracy: 0.9100 - val_loss: 0.2938 - val_accuracy: 0.8952
# Epoch 48/50
# 750/750 - 4s - loss: 0.2634 - accuracy: 0.9094 - val_loss: 0.2944 - val_accuracy: 0.8953
# Epoch 49/50
# 750/750 - 4s - loss: 0.2618 - accuracy: 0.9103 - val_loss: 0.2937 - val_accuracy: 0.8940
# Epoch 50/50
# 750/750 - 4s - loss: 0.2604 - accuracy: 0.9113 - val_loss: 0.2939 - val_accuracy: 0.8952
# 375/375 - 1s - loss: 0.2939 - accuracy: 0.8952
# Accuracy> 89.52
# Epoch 1/50
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0017s vs `on_train_batch_end` time: 0.0027s). Check your callbacks.
# 750/750 - 4s - loss: 0.9778 - accuracy: 0.7065 - val_loss: 0.6434 - val_accuracy: 0.7917
# Epoch 2/50
# 750/750 - 4s - loss: 0.5697 - accuracy: 0.8137 - val_loss: 0.5269 - val_accuracy: 0.8279
# Epoch 3/50
# 750/750 - 4s - loss: 0.4953 - accuracy: 0.8335 - val_loss: 0.4802 - val_accuracy: 0.8399
# Epoch 4/50
# 750/750 - 4s - loss: 0.4581 - accuracy: 0.8459 - val_loss: 0.4520 - val_accuracy: 0.8457
# Epoch 5/50
# 750/750 - 4s - loss: 0.4329 - accuracy: 0.8540 - val_loss: 0.4332 - val_accuracy: 0.8555
# Epoch 6/50
# 750/750 - 4s - loss: 0.4147 - accuracy: 0.8597 - val_loss: 0.4149 - val_accuracy: 0.8597
# Epoch 7/50
# 750/750 - 4s - loss: 0.4000 - accuracy: 0.8636 - val_loss: 0.4038 - val_accuracy: 0.8625
# Epoch 8/50
# 750/750 - 4s - loss: 0.3884 - accuracy: 0.8677 - val_loss: 0.3937 - val_accuracy: 0.8642
# Epoch 9/50
# 750/750 - 4s - loss: 0.3787 - accuracy: 0.8707 - val_loss: 0.3882 - val_accuracy: 0.8677
# Epoch 10/50
# 750/750 - 4s - loss: 0.3699 - accuracy: 0.8735 - val_loss: 0.3780 - val_accuracy: 0.8727
# Epoch 11/50
# 750/750 - 4s - loss: 0.3625 - accuracy: 0.8757 - val_loss: 0.3726 - val_accuracy: 0.8740
# Epoch 12/50
# 750/750 - 4s - loss: 0.3559 - accuracy: 0.8782 - val_loss: 0.3664 - val_accuracy: 0.8748
# Epoch 13/50
# 750/750 - 4s - loss: 0.3500 - accuracy: 0.8801 - val_loss: 0.3602 - val_accuracy: 0.8768
# Epoch 14/50
# 750/750 - 4s - loss: 0.3444 - accuracy: 0.8811 - val_loss: 0.3577 - val_accuracy: 0.8787
# Epoch 15/50
# 750/750 - 4s - loss: 0.3397 - accuracy: 0.8840 - val_loss: 0.3531 - val_accuracy: 0.8810
# Epoch 16/50
# 750/750 - 4s - loss: 0.3350 - accuracy: 0.8846 - val_loss: 0.3493 - val_accuracy: 0.8819
# Epoch 17/50
# 750/750 - 4s - loss: 0.3310 - accuracy: 0.8864 - val_loss: 0.3462 - val_accuracy: 0.8840
# Epoch 18/50
# 750/750 - 4s - loss: 0.3271 - accuracy: 0.8873 - val_loss: 0.3449 - val_accuracy: 0.8822
# Epoch 19/50
# 750/750 - 4s - loss: 0.3231 - accuracy: 0.8889 - val_loss: 0.3423 - val_accuracy: 0.8837
# Epoch 20/50
# 750/750 - 4s - loss: 0.3198 - accuracy: 0.8898 - val_loss: 0.3367 - val_accuracy: 0.8858
# Epoch 21/50
# 750/750 - 4s - loss: 0.3165 - accuracy: 0.8915 - val_loss: 0.3349 - val_accuracy: 0.8882
# Epoch 22/50
# 750/750 - 4s - loss: 0.3133 - accuracy: 0.8914 - val_loss: 0.3349 - val_accuracy: 0.8850
# Epoch 23/50
# 750/750 - 4s - loss: 0.3103 - accuracy: 0.8934 - val_loss: 0.3296 - val_accuracy: 0.8867
# Epoch 24/50
# 750/750 - 4s - loss: 0.3079 - accuracy: 0.8939 - val_loss: 0.3297 - val_accuracy: 0.8873
# Epoch 25/50
# 750/750 - 4s - loss: 0.3051 - accuracy: 0.8941 - val_loss: 0.3277 - val_accuracy: 0.8883
# Epoch 26/50
# 750/750 - 4s - loss: 0.3025 - accuracy: 0.8963 - val_loss: 0.3283 - val_accuracy: 0.8873
# Epoch 27/50
# 750/750 - 4s - loss: 0.3000 - accuracy: 0.8964 - val_loss: 0.3223 - val_accuracy: 0.8892
# Epoch 28/50
# 750/750 - 4s - loss: 0.2977 - accuracy: 0.8973 - val_loss: 0.3208 - val_accuracy: 0.8892
# Epoch 29/50
# 750/750 - 4s - loss: 0.2955 - accuracy: 0.8979 - val_loss: 0.3205 - val_accuracy: 0.8896
# Epoch 30/50
# 750/750 - 4s - loss: 0.2930 - accuracy: 0.8988 - val_loss: 0.3180 - val_accuracy: 0.8913
# Epoch 31/50
# 750/750 - 4s - loss: 0.2911 - accuracy: 0.8992 - val_loss: 0.3187 - val_accuracy: 0.8913
# Epoch 32/50
# 750/750 - 4s - loss: 0.2888 - accuracy: 0.9000 - val_loss: 0.3159 - val_accuracy: 0.8908
# Epoch 33/50
# 750/750 - 4s - loss: 0.2870 - accuracy: 0.8992 - val_loss: 0.3130 - val_accuracy: 0.8930
# Epoch 34/50
# 750/750 - 4s - loss: 0.2846 - accuracy: 0.9021 - val_loss: 0.3107 - val_accuracy: 0.8942
# Epoch 35/50
# 750/750 - 4s - loss: 0.2830 - accuracy: 0.9022 - val_loss: 0.3146 - val_accuracy: 0.8914
# Epoch 36/50
# 750/750 - 4s - loss: 0.2811 - accuracy: 0.9031 - val_loss: 0.3090 - val_accuracy: 0.8938
# Epoch 37/50
# 750/750 - 4s - loss: 0.2791 - accuracy: 0.9023 - val_loss: 0.3078 - val_accuracy: 0.8947
# Epoch 38/50
# 750/750 - 4s - loss: 0.2777 - accuracy: 0.9030 - val_loss: 0.3067 - val_accuracy: 0.8935
# Epoch 39/50
# 750/750 - 4s - loss: 0.2759 - accuracy: 0.9045 - val_loss: 0.3070 - val_accuracy: 0.8953
# Epoch 40/50
# 750/750 - 4s - loss: 0.2738 - accuracy: 0.9048 - val_loss: 0.3046 - val_accuracy: 0.8957
# Epoch 41/50
# 750/750 - 4s - loss: 0.2727 - accuracy: 0.9046 - val_loss: 0.3029 - val_accuracy: 0.8957
# Epoch 42/50
# 750/750 - 4s - loss: 0.2710 - accuracy: 0.9065 - val_loss: 0.3049 - val_accuracy: 0.8963
# Epoch 43/50
# 750/750 - 4s - loss: 0.2694 - accuracy: 0.9059 - val_loss: 0.3021 - val_accuracy: 0.8959
# Epoch 44/50
# 750/750 - 4s - loss: 0.2676 - accuracy: 0.9070 - val_loss: 0.3041 - val_accuracy: 0.8938
# Epoch 45/50
# 750/750 - 4s - loss: 0.2659 - accuracy: 0.9071 - val_loss: 0.2988 - val_accuracy: 0.8978
# Epoch 46/50
# 750/750 - 4s - loss: 0.2649 - accuracy: 0.9074 - val_loss: 0.2988 - val_accuracy: 0.8979
# Epoch 47/50
# 750/750 - 4s - loss: 0.2631 - accuracy: 0.9085 - val_loss: 0.2970 - val_accuracy: 0.8974
# Epoch 48/50
# 750/750 - 4s - loss: 0.2618 - accuracy: 0.9091 - val_loss: 0.2975 - val_accuracy: 0.8957
# Epoch 49/50
# 750/750 - 4s - loss: 0.2607 - accuracy: 0.9092 - val_loss: 0.2975 - val_accuracy: 0.8980
# Epoch 50/50
# 750/750 - 4s - loss: 0.2593 - accuracy: 0.9098 - val_loss: 0.2954 - val_accuracy: 0.8967
# 375/375 - 1s - loss: 0.2954 - accuracy: 0.8967
# Accuracy> 89.67
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:74: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:79: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
