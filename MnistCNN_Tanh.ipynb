# %%
from numpy import mean
from numpy import std
from matplotlib import pyplot
from sklearn.model_selection import KFold
from keras.datasets import fashion_mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import Adadelta, Adam, SGD
 
# load train and test dataset
def load_dataset():
	# load dataset
	(trainX, trainY), (testX, testY) = fashion_mnist.load_data()
	# reshape dataset to have a single channel
	trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
	testX = testX.reshape((testX.shape[0], 28, 28, 1))
	# one hot encode target values
	trainY = to_categorical(trainY)
	testY = to_categorical(testY)
	return trainX, trainY, testX, testY
 
# scale
def prep_pixels(train, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')
	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0
	return train_norm, test_norm

#cnn model with Tanh
def define_model():
  model = Sequential()
  model.add(Conv2D(32, (3, 3), activation='tanh', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
  model.add(MaxPooling2D((2, 2)))
  model.add(Flatten())
  model.add(Dense(100, activation='tanh', kernel_initializer='he_uniform'))
  # model.add(Dropout(rate=0.3))
  model.add(Dense(10, activation='softmax'))
	# compile
  opt = Adadelta(lr=0.01)
  model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
  return model
 
# evaluate the model using k-fold cross-validation
def evaluate_model(dataX, dataY, n_folds=5):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=1)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows of train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit
		history = model.fit(trainX, trainY, epochs=50, batch_size=64, validation_data=(testX, testY), verbose=2)
		# evaluate 
		_, acc = model.evaluate(testX, testY, verbose=2)
		print('Accuracy> %.2f' % (acc * 100.0))
		# append scores
		scores.append(acc)
		histories.append(history)
	return scores, histories

pyplot.figure(figsize=(14,6))
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(211)
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='test')
		# plot accuracy
		pyplot.subplot(212)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()
 
 
# run the code
def run_test():
	# load dataset
	trainX, trainY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, testX = prep_pixels(trainX, testX)
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
	# learning curves
	summarize_diagnostics(histories)


run_test()
# Out:
# Using TensorFlow backend.
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 5us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
#  - 9s - loss: 0.9342 - accuracy: 0.7250 - val_loss: 0.6126 - val_accuracy: 0.8098
# Epoch 2/50
#  - 3s - loss: 0.5466 - accuracy: 0.8244 - val_loss: 0.5096 - val_accuracy: 0.8317
# Epoch 3/50
#  - 3s - loss: 0.4813 - accuracy: 0.8411 - val_loss: 0.4658 - val_accuracy: 0.8445
# Epoch 4/50
#  - 3s - loss: 0.4476 - accuracy: 0.8513 - val_loss: 0.4421 - val_accuracy: 0.8482
# Epoch 5/50
#  - 3s - loss: 0.4251 - accuracy: 0.8570 - val_loss: 0.4237 - val_accuracy: 0.8557
# Epoch 6/50
#  - 3s - loss: 0.4080 - accuracy: 0.8629 - val_loss: 0.4078 - val_accuracy: 0.8613
# Epoch 7/50
#  - 3s - loss: 0.3946 - accuracy: 0.8662 - val_loss: 0.3958 - val_accuracy: 0.8640
# Epoch 8/50
#  - 3s - loss: 0.3834 - accuracy: 0.8710 - val_loss: 0.3860 - val_accuracy: 0.8664
# Epoch 9/50
#  - 3s - loss: 0.3741 - accuracy: 0.8738 - val_loss: 0.3789 - val_accuracy: 0.8681
# Epoch 10/50
#  - 3s - loss: 0.3656 - accuracy: 0.8770 - val_loss: 0.3739 - val_accuracy: 0.8709
# Epoch 11/50
#  - 3s - loss: 0.3582 - accuracy: 0.8786 - val_loss: 0.3645 - val_accuracy: 0.8740
# Epoch 12/50
#  - 3s - loss: 0.3520 - accuracy: 0.8801 - val_loss: 0.3580 - val_accuracy: 0.8750
# Epoch 13/50
#  - 3s - loss: 0.3459 - accuracy: 0.8827 - val_loss: 0.3535 - val_accuracy: 0.8773
# Epoch 14/50
#  - 3s - loss: 0.3404 - accuracy: 0.8844 - val_loss: 0.3501 - val_accuracy: 0.8781
# Epoch 15/50
#  - 3s - loss: 0.3354 - accuracy: 0.8862 - val_loss: 0.3458 - val_accuracy: 0.8792
# Epoch 16/50
#  - 3s - loss: 0.3308 - accuracy: 0.8880 - val_loss: 0.3415 - val_accuracy: 0.8800
# Epoch 17/50
#  - 3s - loss: 0.3267 - accuracy: 0.8896 - val_loss: 0.3382 - val_accuracy: 0.8812
# Epoch 18/50
#  - 3s - loss: 0.3229 - accuracy: 0.8913 - val_loss: 0.3334 - val_accuracy: 0.8822
# Epoch 19/50
#  - 3s - loss: 0.3191 - accuracy: 0.8920 - val_loss: 0.3326 - val_accuracy: 0.8844
# Epoch 20/50
#  - 3s - loss: 0.3157 - accuracy: 0.8934 - val_loss: 0.3338 - val_accuracy: 0.8804
# Epoch 21/50
#  - 3s - loss: 0.3124 - accuracy: 0.8946 - val_loss: 0.3275 - val_accuracy: 0.8841
# Epoch 22/50
#  - 3s - loss: 0.3090 - accuracy: 0.8947 - val_loss: 0.3248 - val_accuracy: 0.8852
# Epoch 23/50
#  - 3s - loss: 0.3061 - accuracy: 0.8959 - val_loss: 0.3218 - val_accuracy: 0.8869
# Epoch 24/50
#  - 3s - loss: 0.3033 - accuracy: 0.8967 - val_loss: 0.3180 - val_accuracy: 0.8868
# Epoch 25/50
#  - 3s - loss: 0.3005 - accuracy: 0.8985 - val_loss: 0.3195 - val_accuracy: 0.8858
# Epoch 26/50
#  - 3s - loss: 0.2979 - accuracy: 0.8987 - val_loss: 0.3151 - val_accuracy: 0.8882
# Epoch 27/50
#  - 3s - loss: 0.2951 - accuracy: 0.8994 - val_loss: 0.3133 - val_accuracy: 0.8884
# Epoch 28/50
#  - 3s - loss: 0.2928 - accuracy: 0.9006 - val_loss: 0.3109 - val_accuracy: 0.8912
# Epoch 29/50
#  - 3s - loss: 0.2904 - accuracy: 0.9002 - val_loss: 0.3081 - val_accuracy: 0.8902
# Epoch 30/50
#  - 3s - loss: 0.2883 - accuracy: 0.9020 - val_loss: 0.3078 - val_accuracy: 0.8907
# Epoch 31/50
#  - 3s - loss: 0.2859 - accuracy: 0.9024 - val_loss: 0.3047 - val_accuracy: 0.8930
# Epoch 32/50
#  - 3s - loss: 0.2839 - accuracy: 0.9038 - val_loss: 0.3031 - val_accuracy: 0.8927
# Epoch 33/50
#  - 3s - loss: 0.2818 - accuracy: 0.9043 - val_loss: 0.3083 - val_accuracy: 0.8892
# Epoch 34/50
#  - 3s - loss: 0.2797 - accuracy: 0.9050 - val_loss: 0.3010 - val_accuracy: 0.8936
# Epoch 35/50
#  - 3s - loss: 0.2777 - accuracy: 0.9063 - val_loss: 0.2997 - val_accuracy: 0.8950
# Epoch 36/50
#  - 3s - loss: 0.2763 - accuracy: 0.9056 - val_loss: 0.3009 - val_accuracy: 0.8913
# Epoch 37/50
#  - 3s - loss: 0.2740 - accuracy: 0.9064 - val_loss: 0.2988 - val_accuracy: 0.8942
# Epoch 38/50
#  - 3s - loss: 0.2722 - accuracy: 0.9071 - val_loss: 0.3000 - val_accuracy: 0.8917
# Epoch 39/50
#  - 3s - loss: 0.2708 - accuracy: 0.9079 - val_loss: 0.2995 - val_accuracy: 0.8913
# Epoch 40/50
#  - 3s - loss: 0.2688 - accuracy: 0.9089 - val_loss: 0.2984 - val_accuracy: 0.8935
# Epoch 41/50
#  - 3s - loss: 0.2673 - accuracy: 0.9091 - val_loss: 0.2947 - val_accuracy: 0.8943
# Epoch 42/50
#  - 3s - loss: 0.2655 - accuracy: 0.9098 - val_loss: 0.2915 - val_accuracy: 0.8966
# Epoch 43/50
#  - 3s - loss: 0.2641 - accuracy: 0.9108 - val_loss: 0.2904 - val_accuracy: 0.8969
# Epoch 44/50
#  - 3s - loss: 0.2623 - accuracy: 0.9113 - val_loss: 0.2888 - val_accuracy: 0.8979
# Epoch 45/50
#  - 3s - loss: 0.2609 - accuracy: 0.9111 - val_loss: 0.2892 - val_accuracy: 0.8963
# Epoch 46/50
#  - 3s - loss: 0.2596 - accuracy: 0.9116 - val_loss: 0.2879 - val_accuracy: 0.8970
# Epoch 47/50
#  - 3s - loss: 0.2580 - accuracy: 0.9123 - val_loss: 0.2860 - val_accuracy: 0.8986
# Epoch 48/50
#  - 3s - loss: 0.2567 - accuracy: 0.9121 - val_loss: 0.2845 - val_accuracy: 0.8994
# Epoch 49/50
#  - 3s - loss: 0.2553 - accuracy: 0.9139 - val_loss: 0.2851 - val_accuracy: 0.8979
# Epoch 50/50
#  - 3s - loss: 0.2537 - accuracy: 0.9134 - val_loss: 0.2869 - val_accuracy: 0.8972
# Accuracy> 89.72
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
#  - 3s - loss: 0.9156 - accuracy: 0.7187 - val_loss: 0.6113 - val_accuracy: 0.7993
# Epoch 2/50
#  - 3s - loss: 0.5543 - accuracy: 0.8173 - val_loss: 0.5096 - val_accuracy: 0.8285
# Epoch 3/50
#  - 3s - loss: 0.4874 - accuracy: 0.8376 - val_loss: 0.4641 - val_accuracy: 0.8409
# Epoch 4/50
#  - 3s - loss: 0.4524 - accuracy: 0.8489 - val_loss: 0.4375 - val_accuracy: 0.8503
# Epoch 5/50
#  - 3s - loss: 0.4290 - accuracy: 0.8550 - val_loss: 0.4195 - val_accuracy: 0.8551
# Epoch 6/50
#  - 3s - loss: 0.4122 - accuracy: 0.8605 - val_loss: 0.4062 - val_accuracy: 0.8580
# Epoch 7/50
#  - 3s - loss: 0.3987 - accuracy: 0.8648 - val_loss: 0.3951 - val_accuracy: 0.8620
# Epoch 8/50
#  - 3s - loss: 0.3875 - accuracy: 0.8682 - val_loss: 0.3861 - val_accuracy: 0.8636
# Epoch 9/50
#  - 3s - loss: 0.3781 - accuracy: 0.8719 - val_loss: 0.3765 - val_accuracy: 0.8677
# Epoch 10/50
#  - 3s - loss: 0.3700 - accuracy: 0.8736 - val_loss: 0.3714 - val_accuracy: 0.8673
# Epoch 11/50
#  - 3s - loss: 0.3630 - accuracy: 0.8764 - val_loss: 0.3623 - val_accuracy: 0.8722
# Epoch 12/50
#  - 3s - loss: 0.3566 - accuracy: 0.8780 - val_loss: 0.3586 - val_accuracy: 0.8729
# Epoch 13/50
#  - 3s - loss: 0.3511 - accuracy: 0.8805 - val_loss: 0.3517 - val_accuracy: 0.8763
# Epoch 14/50
#  - 3s - loss: 0.3455 - accuracy: 0.8820 - val_loss: 0.3488 - val_accuracy: 0.8777
# Epoch 15/50
#  - 3s - loss: 0.3405 - accuracy: 0.8833 - val_loss: 0.3450 - val_accuracy: 0.8782
# Epoch 16/50
#  - 3s - loss: 0.3364 - accuracy: 0.8849 - val_loss: 0.3392 - val_accuracy: 0.8807
# Epoch 17/50
#  - 3s - loss: 0.3320 - accuracy: 0.8867 - val_loss: 0.3385 - val_accuracy: 0.8819
# Epoch 18/50
#  - 3s - loss: 0.3283 - accuracy: 0.8880 - val_loss: 0.3353 - val_accuracy: 0.8816
# Epoch 19/50
#  - 3s - loss: 0.3248 - accuracy: 0.8881 - val_loss: 0.3315 - val_accuracy: 0.8816
# Epoch 20/50
#  - 3s - loss: 0.3214 - accuracy: 0.8893 - val_loss: 0.3268 - val_accuracy: 0.8867
# Epoch 21/50
#  - 3s - loss: 0.3178 - accuracy: 0.8911 - val_loss: 0.3277 - val_accuracy: 0.8827
# Epoch 22/50
#  - 3s - loss: 0.3149 - accuracy: 0.8921 - val_loss: 0.3216 - val_accuracy: 0.8873
# Epoch 23/50
#  - 3s - loss: 0.3119 - accuracy: 0.8925 - val_loss: 0.3206 - val_accuracy: 0.8879
# Epoch 24/50
#  - 3s - loss: 0.3090 - accuracy: 0.8940 - val_loss: 0.3202 - val_accuracy: 0.8863
# Epoch 25/50
#  - 3s - loss: 0.3061 - accuracy: 0.8950 - val_loss: 0.3172 - val_accuracy: 0.8880
# Epoch 26/50
#  - 3s - loss: 0.3043 - accuracy: 0.8946 - val_loss: 0.3134 - val_accuracy: 0.8891
# Epoch 27/50
#  - 3s - loss: 0.3015 - accuracy: 0.8959 - val_loss: 0.3102 - val_accuracy: 0.8917
# Epoch 28/50
#  - 3s - loss: 0.2989 - accuracy: 0.8972 - val_loss: 0.3106 - val_accuracy: 0.8906
# Epoch 29/50
#  - 3s - loss: 0.2971 - accuracy: 0.8980 - val_loss: 0.3100 - val_accuracy: 0.8918
# Epoch 30/50
#  - 3s - loss: 0.2946 - accuracy: 0.8986 - val_loss: 0.3057 - val_accuracy: 0.8927
# Epoch 31/50
#  - 3s - loss: 0.2926 - accuracy: 0.8990 - val_loss: 0.3045 - val_accuracy: 0.8923
# Epoch 32/50
#  - 3s - loss: 0.2905 - accuracy: 0.8995 - val_loss: 0.3049 - val_accuracy: 0.8932
# Epoch 33/50
#  - 3s - loss: 0.2882 - accuracy: 0.9003 - val_loss: 0.3017 - val_accuracy: 0.8936
# Epoch 34/50
#  - 3s - loss: 0.2864 - accuracy: 0.9011 - val_loss: 0.3020 - val_accuracy: 0.8938
# Epoch 35/50
#  - 3s - loss: 0.2847 - accuracy: 0.9014 - val_loss: 0.2983 - val_accuracy: 0.8953
# Epoch 36/50
#  - 3s - loss: 0.2827 - accuracy: 0.9019 - val_loss: 0.2968 - val_accuracy: 0.8958
# Epoch 37/50
#  - 3s - loss: 0.2807 - accuracy: 0.9027 - val_loss: 0.2974 - val_accuracy: 0.8956
# Epoch 38/50
#  - 3s - loss: 0.2792 - accuracy: 0.9032 - val_loss: 0.2939 - val_accuracy: 0.8972
# Epoch 39/50
#  - 3s - loss: 0.2775 - accuracy: 0.9045 - val_loss: 0.2926 - val_accuracy: 0.8971
# Epoch 40/50
#  - 3s - loss: 0.2758 - accuracy: 0.9045 - val_loss: 0.2924 - val_accuracy: 0.8962
# Epoch 41/50
#  - 3s - loss: 0.2740 - accuracy: 0.9054 - val_loss: 0.2926 - val_accuracy: 0.8973
# Epoch 42/50
#  - 3s - loss: 0.2724 - accuracy: 0.9056 - val_loss: 0.2902 - val_accuracy: 0.8977
# Epoch 43/50
#  - 3s - loss: 0.2713 - accuracy: 0.9069 - val_loss: 0.2903 - val_accuracy: 0.8969
# Epoch 44/50
#  - 3s - loss: 0.2693 - accuracy: 0.9076 - val_loss: 0.2875 - val_accuracy: 0.8999
# Epoch 45/50
#  - 3s - loss: 0.2677 - accuracy: 0.9075 - val_loss: 0.2884 - val_accuracy: 0.8984
# Epoch 46/50
#  - 3s - loss: 0.2662 - accuracy: 0.9082 - val_loss: 0.2867 - val_accuracy: 0.8992
# Epoch 47/50
#  - 3s - loss: 0.2650 - accuracy: 0.9086 - val_loss: 0.2841 - val_accuracy: 0.8997
# Epoch 48/50
#  - 3s - loss: 0.2635 - accuracy: 0.9087 - val_loss: 0.2830 - val_accuracy: 0.8996
# Epoch 49/50
#  - 3s - loss: 0.2624 - accuracy: 0.9098 - val_loss: 0.2839 - val_accuracy: 0.9001
# Epoch 50/50
#  - 3s - loss: 0.2609 - accuracy: 0.9096 - val_loss: 0.2819 - val_accuracy: 0.9007
# Accuracy> 90.07
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
#  - 3s - loss: 0.8940 - accuracy: 0.7320 - val_loss: 0.6068 - val_accuracy: 0.8068
# Epoch 2/50
#  - 3s - loss: 0.5473 - accuracy: 0.8173 - val_loss: 0.5117 - val_accuracy: 0.8320
# Epoch 3/50
#  - 3s - loss: 0.4825 - accuracy: 0.8373 - val_loss: 0.4713 - val_accuracy: 0.8469
# Epoch 4/50
#  - 3s - loss: 0.4472 - accuracy: 0.8484 - val_loss: 0.4427 - val_accuracy: 0.8558
# Epoch 5/50
#  - 3s - loss: 0.4249 - accuracy: 0.8559 - val_loss: 0.4273 - val_accuracy: 0.8587
# Epoch 6/50
#  - 3s - loss: 0.4076 - accuracy: 0.8610 - val_loss: 0.4225 - val_accuracy: 0.8577
# Epoch 7/50
#  - 3s - loss: 0.3942 - accuracy: 0.8654 - val_loss: 0.4019 - val_accuracy: 0.8645
# Epoch 8/50
#  - 3s - loss: 0.3832 - accuracy: 0.8677 - val_loss: 0.3917 - val_accuracy: 0.8698
# Epoch 9/50
#  - 3s - loss: 0.3738 - accuracy: 0.8722 - val_loss: 0.3835 - val_accuracy: 0.8738
# Epoch 10/50
#  - 3s - loss: 0.3654 - accuracy: 0.8749 - val_loss: 0.3788 - val_accuracy: 0.8733
# Epoch 11/50
#  - 3s - loss: 0.3582 - accuracy: 0.8771 - val_loss: 0.3758 - val_accuracy: 0.8740
# Epoch 12/50
#  - 3s - loss: 0.3517 - accuracy: 0.8798 - val_loss: 0.3705 - val_accuracy: 0.8739
# Epoch 13/50
#  - 3s - loss: 0.3460 - accuracy: 0.8820 - val_loss: 0.3613 - val_accuracy: 0.8782
# Epoch 14/50
#  - 3s - loss: 0.3406 - accuracy: 0.8833 - val_loss: 0.3586 - val_accuracy: 0.8783
# Epoch 15/50
#  - 3s - loss: 0.3358 - accuracy: 0.8845 - val_loss: 0.3546 - val_accuracy: 0.8803
# Epoch 16/50
#  - 3s - loss: 0.3314 - accuracy: 0.8856 - val_loss: 0.3491 - val_accuracy: 0.8827
# Epoch 17/50
#  - 3s - loss: 0.3268 - accuracy: 0.8875 - val_loss: 0.3501 - val_accuracy: 0.8805
# Epoch 18/50
#  - 3s - loss: 0.3230 - accuracy: 0.8889 - val_loss: 0.3447 - val_accuracy: 0.8826
# Epoch 19/50
#  - 3s - loss: 0.3192 - accuracy: 0.8898 - val_loss: 0.3392 - val_accuracy: 0.8835
# Epoch 20/50
#  - 3s - loss: 0.3157 - accuracy: 0.8912 - val_loss: 0.3379 - val_accuracy: 0.8847
# Epoch 21/50
#  - 3s - loss: 0.3122 - accuracy: 0.8924 - val_loss: 0.3369 - val_accuracy: 0.8840
# Epoch 22/50
#  - 3s - loss: 0.3092 - accuracy: 0.8935 - val_loss: 0.3325 - val_accuracy: 0.8865
# Epoch 23/50
#  - 3s - loss: 0.3061 - accuracy: 0.8947 - val_loss: 0.3312 - val_accuracy: 0.8871
# Epoch 24/50
#  - 3s - loss: 0.3031 - accuracy: 0.8953 - val_loss: 0.3277 - val_accuracy: 0.8863
# Epoch 25/50
#  - 3s - loss: 0.3005 - accuracy: 0.8963 - val_loss: 0.3278 - val_accuracy: 0.8866
# Epoch 26/50
#  - 3s - loss: 0.2977 - accuracy: 0.8974 - val_loss: 0.3235 - val_accuracy: 0.8892
# Epoch 27/50
#  - 3s - loss: 0.2949 - accuracy: 0.8984 - val_loss: 0.3205 - val_accuracy: 0.8896
# Epoch 28/50
#  - 3s - loss: 0.2924 - accuracy: 0.8992 - val_loss: 0.3205 - val_accuracy: 0.8901
# Epoch 29/50
#  - 3s - loss: 0.2901 - accuracy: 0.9000 - val_loss: 0.3177 - val_accuracy: 0.8911
# Epoch 30/50
#  - 3s - loss: 0.2877 - accuracy: 0.9000 - val_loss: 0.3166 - val_accuracy: 0.8902
# Epoch 31/50
#  - 3s - loss: 0.2856 - accuracy: 0.9018 - val_loss: 0.3150 - val_accuracy: 0.8916
# Epoch 32/50
#  - 3s - loss: 0.2833 - accuracy: 0.9026 - val_loss: 0.3136 - val_accuracy: 0.8920
# Epoch 33/50
#  - 3s - loss: 0.2813 - accuracy: 0.9038 - val_loss: 0.3119 - val_accuracy: 0.8918
# Epoch 34/50
#  - 3s - loss: 0.2789 - accuracy: 0.9039 - val_loss: 0.3112 - val_accuracy: 0.8922
# Epoch 35/50
#  - 3s - loss: 0.2772 - accuracy: 0.9045 - val_loss: 0.3082 - val_accuracy: 0.8940
# Epoch 36/50
#  - 3s - loss: 0.2752 - accuracy: 0.9054 - val_loss: 0.3096 - val_accuracy: 0.8936
# Epoch 37/50
#  - 3s - loss: 0.2734 - accuracy: 0.9057 - val_loss: 0.3100 - val_accuracy: 0.8921
# Epoch 38/50
#  - 3s - loss: 0.2715 - accuracy: 0.9061 - val_loss: 0.3050 - val_accuracy: 0.8938
# Epoch 39/50
#  - 3s - loss: 0.2700 - accuracy: 0.9074 - val_loss: 0.3048 - val_accuracy: 0.8947
# Epoch 40/50
#  - 3s - loss: 0.2681 - accuracy: 0.9072 - val_loss: 0.3030 - val_accuracy: 0.8978
# Epoch 41/50
#  - 3s - loss: 0.2665 - accuracy: 0.9076 - val_loss: 0.3004 - val_accuracy: 0.8967
# Epoch 42/50
#  - 3s - loss: 0.2647 - accuracy: 0.9086 - val_loss: 0.3007 - val_accuracy: 0.8963
# Epoch 43/50
#  - 3s - loss: 0.2632 - accuracy: 0.9096 - val_loss: 0.2976 - val_accuracy: 0.8988
# Epoch 44/50
#  - 3s - loss: 0.2612 - accuracy: 0.9104 - val_loss: 0.2973 - val_accuracy: 0.8984
# Epoch 45/50
#  - 3s - loss: 0.2601 - accuracy: 0.9113 - val_loss: 0.2974 - val_accuracy: 0.8979
# Epoch 46/50
#  - 3s - loss: 0.2587 - accuracy: 0.9111 - val_loss: 0.2961 - val_accuracy: 0.8986
# Epoch 47/50
#  - 3s - loss: 0.2570 - accuracy: 0.9117 - val_loss: 0.2947 - val_accuracy: 0.8978
# Epoch 48/50
#  - 3s - loss: 0.2557 - accuracy: 0.9123 - val_loss: 0.2931 - val_accuracy: 0.8995
# Epoch 49/50
#  - 3s - loss: 0.2542 - accuracy: 0.9126 - val_loss: 0.2920 - val_accuracy: 0.9003
# Epoch 50/50
#  - 3s - loss: 0.2527 - accuracy: 0.9134 - val_loss: 0.2925 - val_accuracy: 0.8997
# Accuracy> 89.97
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
#  - 3s - loss: 0.9017 - accuracy: 0.7331 - val_loss: 0.5999 - val_accuracy: 0.8067
# Epoch 2/50
#  - 3s - loss: 0.5426 - accuracy: 0.8207 - val_loss: 0.4996 - val_accuracy: 0.8342
# Epoch 3/50
#  - 3s - loss: 0.4772 - accuracy: 0.8392 - val_loss: 0.4569 - val_accuracy: 0.8453
# Epoch 4/50
#  - 3s - loss: 0.4424 - accuracy: 0.8512 - val_loss: 0.4378 - val_accuracy: 0.8490
# Epoch 5/50
#  - 3s - loss: 0.4194 - accuracy: 0.8586 - val_loss: 0.4142 - val_accuracy: 0.8575
# Epoch 6/50
#  - 3s - loss: 0.4025 - accuracy: 0.8635 - val_loss: 0.4012 - val_accuracy: 0.8611
# Epoch 7/50
#  - 3s - loss: 0.3891 - accuracy: 0.8680 - val_loss: 0.3895 - val_accuracy: 0.8653
# Epoch 8/50
#  - 3s - loss: 0.3784 - accuracy: 0.8712 - val_loss: 0.3800 - val_accuracy: 0.8687
# Epoch 9/50
#  - 3s - loss: 0.3689 - accuracy: 0.8749 - val_loss: 0.3729 - val_accuracy: 0.8724
# Epoch 10/50
#  - 3s - loss: 0.3609 - accuracy: 0.8770 - val_loss: 0.3658 - val_accuracy: 0.8737
# Epoch 11/50
#  - 3s - loss: 0.3539 - accuracy: 0.8794 - val_loss: 0.3642 - val_accuracy: 0.8735
# Epoch 12/50
#  - 3s - loss: 0.3472 - accuracy: 0.8818 - val_loss: 0.3543 - val_accuracy: 0.8782
# Epoch 13/50
#  - 3s - loss: 0.3416 - accuracy: 0.8840 - val_loss: 0.3505 - val_accuracy: 0.8796
# Epoch 14/50
#  - 3s - loss: 0.3365 - accuracy: 0.8849 - val_loss: 0.3472 - val_accuracy: 0.8803
# Epoch 15/50
#  - 3s - loss: 0.3317 - accuracy: 0.8866 - val_loss: 0.3440 - val_accuracy: 0.8807
# Epoch 16/50
#  - 3s - loss: 0.3274 - accuracy: 0.8878 - val_loss: 0.3385 - val_accuracy: 0.8843
# Epoch 17/50
#  - 3s - loss: 0.3230 - accuracy: 0.8885 - val_loss: 0.3369 - val_accuracy: 0.8830
# Epoch 18/50
#  - 3s - loss: 0.3191 - accuracy: 0.8909 - val_loss: 0.3330 - val_accuracy: 0.8850
# Epoch 19/50
#  - 3s - loss: 0.3155 - accuracy: 0.8920 - val_loss: 0.3292 - val_accuracy: 0.8860
# Epoch 20/50
#  - 3s - loss: 0.3120 - accuracy: 0.8930 - val_loss: 0.3306 - val_accuracy: 0.8852
# Epoch 21/50
#  - 3s - loss: 0.3087 - accuracy: 0.8939 - val_loss: 0.3259 - val_accuracy: 0.8884
# Epoch 22/50
#  - 3s - loss: 0.3056 - accuracy: 0.8961 - val_loss: 0.3234 - val_accuracy: 0.8880
# Epoch 23/50
#  - 3s - loss: 0.3026 - accuracy: 0.8969 - val_loss: 0.3220 - val_accuracy: 0.8877
# Epoch 24/50
#  - 3s - loss: 0.2996 - accuracy: 0.8979 - val_loss: 0.3186 - val_accuracy: 0.8904
# Epoch 25/50
#  - 3s - loss: 0.2969 - accuracy: 0.8984 - val_loss: 0.3166 - val_accuracy: 0.8908
# Epoch 26/50
#  - 3s - loss: 0.2945 - accuracy: 0.8988 - val_loss: 0.3142 - val_accuracy: 0.8901
# Epoch 27/50
#  - 3s - loss: 0.2920 - accuracy: 0.9002 - val_loss: 0.3141 - val_accuracy: 0.8892
# Epoch 28/50
#  - 3s - loss: 0.2895 - accuracy: 0.9013 - val_loss: 0.3115 - val_accuracy: 0.8915
# Epoch 29/50
#  - 3s - loss: 0.2873 - accuracy: 0.9022 - val_loss: 0.3090 - val_accuracy: 0.8913
# Epoch 30/50
#  - 3s - loss: 0.2850 - accuracy: 0.9027 - val_loss: 0.3076 - val_accuracy: 0.8937
# Epoch 31/50
#  - 3s - loss: 0.2826 - accuracy: 0.9034 - val_loss: 0.3073 - val_accuracy: 0.8931
# Epoch 32/50
#  - 3s - loss: 0.2806 - accuracy: 0.9042 - val_loss: 0.3049 - val_accuracy: 0.8931
# Epoch 33/50
#  - 3s - loss: 0.2788 - accuracy: 0.9049 - val_loss: 0.3036 - val_accuracy: 0.8933
# Epoch 34/50
#  - 3s - loss: 0.2766 - accuracy: 0.9053 - val_loss: 0.3015 - val_accuracy: 0.8945
# Epoch 35/50
#  - 3s - loss: 0.2746 - accuracy: 0.9061 - val_loss: 0.3013 - val_accuracy: 0.8967
# Epoch 36/50
#  - 3s - loss: 0.2727 - accuracy: 0.9075 - val_loss: 0.2998 - val_accuracy: 0.8961
# Epoch 37/50
#  - 3s - loss: 0.2711 - accuracy: 0.9064 - val_loss: 0.2984 - val_accuracy: 0.8947
# Epoch 38/50
#  - 3s - loss: 0.2691 - accuracy: 0.9081 - val_loss: 0.2974 - val_accuracy: 0.8946
# Epoch 39/50
#  - 3s - loss: 0.2678 - accuracy: 0.9085 - val_loss: 0.2962 - val_accuracy: 0.8947
# Epoch 40/50
#  - 3s - loss: 0.2658 - accuracy: 0.9090 - val_loss: 0.2949 - val_accuracy: 0.8967
# Epoch 41/50
#  - 3s - loss: 0.2640 - accuracy: 0.9095 - val_loss: 0.2949 - val_accuracy: 0.8950
# Epoch 42/50
#  - 3s - loss: 0.2625 - accuracy: 0.9097 - val_loss: 0.2948 - val_accuracy: 0.8952
# Epoch 43/50
#  - 3s - loss: 0.2612 - accuracy: 0.9105 - val_loss: 0.2929 - val_accuracy: 0.8947
# Epoch 44/50
#  - 3s - loss: 0.2594 - accuracy: 0.9114 - val_loss: 0.2905 - val_accuracy: 0.8975
# Epoch 45/50
#  - 3s - loss: 0.2581 - accuracy: 0.9115 - val_loss: 0.2940 - val_accuracy: 0.8963
# Epoch 46/50
#  - 3s - loss: 0.2566 - accuracy: 0.9122 - val_loss: 0.2903 - val_accuracy: 0.8972
# Epoch 47/50
#  - 3s - loss: 0.2547 - accuracy: 0.9132 - val_loss: 0.2907 - val_accuracy: 0.8974
# Epoch 48/50
#  - 3s - loss: 0.2535 - accuracy: 0.9134 - val_loss: 0.2891 - val_accuracy: 0.8974
# Epoch 49/50
#  - 3s - loss: 0.2522 - accuracy: 0.9138 - val_loss: 0.2863 - val_accuracy: 0.8988
# Epoch 50/50
#  - 3s - loss: 0.2506 - accuracy: 0.9144 - val_loss: 0.2868 - val_accuracy: 0.8993
# Accuracy> 89.93
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
#  - 3s - loss: 0.9014 - accuracy: 0.7254 - val_loss: 0.6153 - val_accuracy: 0.8004
# Epoch 2/50
#  - 3s - loss: 0.5513 - accuracy: 0.8180 - val_loss: 0.5137 - val_accuracy: 0.8268
# Epoch 3/50
#  - 3s - loss: 0.4850 - accuracy: 0.8357 - val_loss: 0.4687 - val_accuracy: 0.8450
# Epoch 4/50
#  - 3s - loss: 0.4495 - accuracy: 0.8479 - val_loss: 0.4409 - val_accuracy: 0.8538
# Epoch 5/50
#  - 3s - loss: 0.4261 - accuracy: 0.8558 - val_loss: 0.4214 - val_accuracy: 0.8587
# Epoch 6/50
#  - 3s - loss: 0.4090 - accuracy: 0.8609 - val_loss: 0.4071 - val_accuracy: 0.8645
# Epoch 7/50
#  - 3s - loss: 0.3955 - accuracy: 0.8656 - val_loss: 0.3975 - val_accuracy: 0.8653
# Epoch 8/50
#  - 3s - loss: 0.3843 - accuracy: 0.8690 - val_loss: 0.3876 - val_accuracy: 0.8696
# Epoch 9/50
#  - 3s - loss: 0.3752 - accuracy: 0.8722 - val_loss: 0.3793 - val_accuracy: 0.8732
# Epoch 10/50
#  - 3s - loss: 0.3670 - accuracy: 0.8749 - val_loss: 0.3778 - val_accuracy: 0.8712
# Epoch 11/50
#  - 3s - loss: 0.3598 - accuracy: 0.8769 - val_loss: 0.3663 - val_accuracy: 0.8757
# Epoch 12/50
#  - 3s - loss: 0.3532 - accuracy: 0.8784 - val_loss: 0.3619 - val_accuracy: 0.8794
# Epoch 13/50
#  - 3s - loss: 0.3473 - accuracy: 0.8817 - val_loss: 0.3604 - val_accuracy: 0.8792
# Epoch 14/50
#  - 3s - loss: 0.3418 - accuracy: 0.8827 - val_loss: 0.3524 - val_accuracy: 0.8827
# Epoch 15/50
#  - 3s - loss: 0.3371 - accuracy: 0.8845 - val_loss: 0.3482 - val_accuracy: 0.8828
# Epoch 16/50
#  - 3s - loss: 0.3325 - accuracy: 0.8861 - val_loss: 0.3443 - val_accuracy: 0.8858
# Epoch 17/50
#  - 3s - loss: 0.3281 - accuracy: 0.8877 - val_loss: 0.3426 - val_accuracy: 0.8833
# Epoch 18/50
#  - 3s - loss: 0.3242 - accuracy: 0.8892 - val_loss: 0.3409 - val_accuracy: 0.8856
# Epoch 19/50
#  - 3s - loss: 0.3204 - accuracy: 0.8895 - val_loss: 0.3352 - val_accuracy: 0.8865
# Epoch 20/50
#  - 3s - loss: 0.3169 - accuracy: 0.8909 - val_loss: 0.3321 - val_accuracy: 0.8878
# Epoch 21/50
#  - 3s - loss: 0.3134 - accuracy: 0.8925 - val_loss: 0.3349 - val_accuracy: 0.8863
# Epoch 22/50
#  - 3s - loss: 0.3104 - accuracy: 0.8933 - val_loss: 0.3290 - val_accuracy: 0.8878
# Epoch 23/50
#  - 3s - loss: 0.3073 - accuracy: 0.8942 - val_loss: 0.3278 - val_accuracy: 0.8873
# Epoch 24/50
#  - 3s - loss: 0.3047 - accuracy: 0.8948 - val_loss: 0.3244 - val_accuracy: 0.8902
# Epoch 25/50
#  - 3s - loss: 0.3017 - accuracy: 0.8955 - val_loss: 0.3224 - val_accuracy: 0.8901
# Epoch 26/50
#  - 3s - loss: 0.2990 - accuracy: 0.8968 - val_loss: 0.3185 - val_accuracy: 0.8911
# Epoch 27/50
#  - 3s - loss: 0.2967 - accuracy: 0.8983 - val_loss: 0.3173 - val_accuracy: 0.8917
# Epoch 28/50
#  - 3s - loss: 0.2944 - accuracy: 0.8980 - val_loss: 0.3167 - val_accuracy: 0.8923
# Epoch 29/50
#  - 3s - loss: 0.2914 - accuracy: 0.8994 - val_loss: 0.3134 - val_accuracy: 0.8928
# Epoch 30/50
#  - 3s - loss: 0.2893 - accuracy: 0.9005 - val_loss: 0.3122 - val_accuracy: 0.8927
# Epoch 31/50
#  - 3s - loss: 0.2872 - accuracy: 0.9012 - val_loss: 0.3115 - val_accuracy: 0.8942
# Epoch 32/50
#  - 3s - loss: 0.2852 - accuracy: 0.9013 - val_loss: 0.3130 - val_accuracy: 0.8916
# Epoch 33/50
#  - 3s - loss: 0.2830 - accuracy: 0.9022 - val_loss: 0.3084 - val_accuracy: 0.8953
# Epoch 34/50
#  - 3s - loss: 0.2810 - accuracy: 0.9031 - val_loss: 0.3056 - val_accuracy: 0.8965
# Epoch 35/50
#  - 3s - loss: 0.2790 - accuracy: 0.9050 - val_loss: 0.3037 - val_accuracy: 0.8978
# Epoch 36/50
#  - 3s - loss: 0.2771 - accuracy: 0.9041 - val_loss: 0.3025 - val_accuracy: 0.8968
# Epoch 37/50
#  - 3s - loss: 0.2753 - accuracy: 0.9051 - val_loss: 0.3020 - val_accuracy: 0.8972
# Epoch 38/50
#  - 3s - loss: 0.2735 - accuracy: 0.9053 - val_loss: 0.3033 - val_accuracy: 0.8963
# Epoch 39/50
#  - 3s - loss: 0.2717 - accuracy: 0.9057 - val_loss: 0.2994 - val_accuracy: 0.8982
# Epoch 40/50
#  - 3s - loss: 0.2700 - accuracy: 0.9068 - val_loss: 0.2979 - val_accuracy: 0.8992
# Epoch 41/50
#  - 3s - loss: 0.2682 - accuracy: 0.9077 - val_loss: 0.2981 - val_accuracy: 0.8989
# Epoch 42/50
#  - 3s - loss: 0.2665 - accuracy: 0.9078 - val_loss: 0.2952 - val_accuracy: 0.9003
# Epoch 43/50
#  - 3s - loss: 0.2648 - accuracy: 0.9079 - val_loss: 0.2963 - val_accuracy: 0.8995
# Epoch 44/50
#  - 3s - loss: 0.2632 - accuracy: 0.9094 - val_loss: 0.2973 - val_accuracy: 0.8970
# Epoch 45/50
#  - 3s - loss: 0.2618 - accuracy: 0.9098 - val_loss: 0.2935 - val_accuracy: 0.8999
# Epoch 46/50
#  - 3s - loss: 0.2605 - accuracy: 0.9099 - val_loss: 0.2975 - val_accuracy: 0.8971
# Epoch 47/50
#  - 3s - loss: 0.2587 - accuracy: 0.9113 - val_loss: 0.2918 - val_accuracy: 0.9014
# Epoch 48/50
#  - 3s - loss: 0.2574 - accuracy: 0.9110 - val_loss: 0.2911 - val_accuracy: 0.9010
# Epoch 49/50
#  - 3s - loss: 0.2559 - accuracy: 0.9119 - val_loss: 0.2907 - val_accuracy: 0.9003
# Epoch 50/50
#  - 3s - loss: 0.2546 - accuracy: 0.9125 - val_loss: 0.2872 - val_accuracy: 0.9032
# Accuracy> 90.32
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:74: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:79: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
